# %%
import pandas as pd
import matplotlib.pyplot as plt


maskbycounty= pd.read_csv('https://raw.githubusercontent.com/peterger8y/covid-19-data/master/mask-use/mask-use-by-county.csv')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/live/us-counties.csv')

# %%
lister = ['https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-56.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-55.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-54.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-53.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-51.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-50.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-49.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-48.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-47.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-46.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-45.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-44.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-42.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-41.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-40.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-39.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-38.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-37.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-36.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-35.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-34.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-33.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-32.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-31.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-30.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-29.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-28.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-27.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-26.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-25.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-24.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-23.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-22.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-21.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-20.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-19.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-18.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-17.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-16.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-15.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-13.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-12.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-11.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-10.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-09.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-08.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-06.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-05.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-04.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-02.csv', 
          'https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/asrh/cc-est2019-agesex-01.csv']

# %%
zardoz = []
zardoz = pd.DataFrame(zardoz)
for x in lister:
  delta = pd.read_csv(x, encoding='latin-1')
  zardoz = pd.concat([zardoz, delta], ignore_index=True)

# %%
i = zardoz['YEAR'] == 12
zardoz = zardoz[i]

bn = ['SUMLEV', 'STATE', 'COUNTY', 'YEAR']

zardoz.drop(labels = bn, axis=1)
# Out:
#         STNAME            CTYNAME  ...  MEDIAN_AGE_MALE  MEDIAN_AGE_FEM
# 11     Wyoming      Albany County  ...             27.6            28.3
# 23     Wyoming    Big Horn County  ...             41.2            42.6
# 35     Wyoming    Campbell County  ...             34.9            35.3
# 47     Wyoming      Carbon County  ...             38.7            40.3
# 59     Wyoming    Converse County  ...             39.6            40.2
# ...        ...                ...  ...              ...             ...
# 37655  Alabama  Tuscaloosa County  ...             32.3            34.9
# 37667  Alabama      Walker County  ...             40.5            43.6
# 37679  Alabama  Washington County  ...             41.2            44.5
# 37691  Alabama      Wilcox County  ...             38.6            42.3
# 37703  Alabama     Winston County  ...             44.6            46.6
#
# [3142 rows x 92 columns]

# %%
kumbaya = []
for x in zardoz['CTYNAME']:
  x = x.split(' ')
  if x[-1] == 'County':
    x.pop()
    x =' '.join(x)
    kumbaya.append(x)
  else:
    x= ' '.join(x)
    kumbaya.append(x)

# %%
zardoz['CTYNAME'] = kumbaya
zardoz.shape
# Out:
# (3142, 96)

# %%
zardoz.reset_index(inplace=True)

# %%
zardoz.head()
# Out:
#    index  SUMLEV  STATE  ...  MEDIAN_AGE_TOT MEDIAN_AGE_MALE MEDIAN_AGE_FEM
# 0     11      50     56  ...            27.9            27.6           28.3
# 1     23      50     56  ...            41.8            41.2           42.6
# 2     35      50     56  ...            35.1            34.9           35.3
# 3     47      50     56  ...            39.4            38.7           40.3
# 4     59      50     56  ...            39.8            39.6           40.2
#
# [5 rows x 97 columns]

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %%
galla = []
for x in zardoz['STNAME']:
  galla.append(us_state_abbrev[x])

# %%
zardoz['STNAME'] = galla

# %%
dfhere = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/live/us-counties.csv')

dfhere.head()
# Out:
#          date   county  ... probable_cases  probable_deaths
# 0  2021-01-11  Autauga  ...          555.0              7.0
# 1  2021-01-11  Baldwin  ...         4205.0             48.0
# 2  2021-01-11  Barbour  ...          710.0              7.0
# 3  2021-01-11     Bibb  ...          349.0             20.0
# 4  2021-01-11   Blount  ...         1210.0              9.0
#
# [5 rows x 10 columns]

# %%
exon = pd.read_csv('/content/finalizederest.csv')

# %%
gabba = []
for x in dfhere['county']:
  x = x.split()
  if x[-1] == 'Area':
    x.pop()
    x.pop()
    x = ' '.join(x)
    gabba.append(x)
  elif x[-1] == 'Borough':
    x.pop()
    x = ' '.join(x)
    gabba.append(x)
  elif x[-1] == 'Municipality':
    x.pop()
    x = ' '.join(x)
    gabba.append(x)
  elif x[-1] == 'city':
    x.pop()
    x = ' '.join(x)
    gabba.append(x)
  elif x[-1] == 'Parish':
    x.pop()
    x = ' '.join(x)
    gabba.append(x)
  else:
    x = ' '.join(x)
    gabba.append(x)

# %%
dfhere['county'] = gabba

# %%
gabba = []

for x in dfhere['state']:
  gabba.append(us_state_abbrev[x])

dfhere['state'] = gabba

# %%
gabba = []

for x in dfhere['county']:
  x = x.split()
  if x[-1] == 'and':
    x.pop()
    x.pop()
    x = ' '.join(x)
    gabba.append(x)
  else:
    x = ' '.join(x)
    gabba.append(x)

dfhere['county'] = gabba
gabba
# Out:
# ['Autauga',
#  'Baldwin',
#  'Barbour',
#  'Bibb',
#  'Blount',
#  'Bullock',
#  'Butler',
#  'Calhoun',
#  'Chambers',
#  'Cherokee',
#  'Chilton',
#  'Choctaw',
#  'Clarke',
#  'Clay',
#  'Cleburne',
#  'Coffee',
#  'Colbert',
#  'Conecuh',
#  'Coosa',
#  'Covington',
#  'Crenshaw',
#  'Cullman',
#  'Dale',
#  'Dallas',
#  'DeKalb',
#  'Elmore',
#  'Escambia',
#  'Etowah',
#  'Fayette',
#  'Franklin',
#  'Geneva',
#  'Greene',
#  'Hale',
#  'Henry',
#  'Houston',
#  'Jackson',
#  'Jefferson',
#  'Lamar',
#  'Lauderdale',
#  'Lawrence',
#  'Lee',
#  'Limestone',
#  'Lowndes',
#  'Macon',
#  'Madison',
#  'Marengo',
#  'Marion',
#  'Marshall',
#  'Mobile',
#  'Monroe',
#  'Montgomery',
#  'Morgan',
#  'Perry',
#  'Pickens',
#  'Pike',
#  'Randolph',
#  'Russell',
#  'Shelby',
#  'St. Clair',
#  'Sumter',
#  'Talladega',
#  'Tallapoosa',
#  'Tuscaloosa',
#  'Walker',
#  'Washington',
#  'Wilcox',
#  'Winston',
#  'Aleutians East',
#  'Aleutians West',
#  'Anchorage',
#  'Bethel',
#  'Bristol Bay',
#  'Denali',
#  'Dillingham',
#  'Fairbanks North Star',
#  'Haines',
#  'Juneau',
#  'Kenai Peninsula',
#  'Ketchikan Gateway',
#  'Kodiak Island',
#  'Kusilvak',
#  'Lake and Peninsula',
#  'Matanuska-Susitna',
#  'Nome',
#  'North Slope',
#  'Northwest Arctic',
#  'Petersburg',
#  'Prince of Wales-Hyder',
#  'Sitka',
#  'Skagway',
#  'Southeast Fairbanks',
#  'Unknown',
#  'Valdez-Cordova',
#  'Wrangell',
#  'Yukon-Koyukuk',
#  'Apache',
#  'Cochise',
#  'Coconino',
#  'Gila',
#  'Graham',
#  'Greenlee',
#  'La Paz',
#  'Maricopa',
#  'Mohave',
#  'Navajo',
#  'Pima',
#  'Pinal',
#  'Santa Cruz',
#  'Yavapai',
#  'Yuma',
#  'Arkansas',
#  'Ashley',
#  'Baxter',
#  'Benton',
#  'Boone',
#  'Bradley',
#  'Calhoun',
#  'Carroll',
#  'Chicot',
#  'Clark',
#  'Clay',
#  'Cleburne',
#  'Cleveland',
#  'Columbia',
#  'Conway',
#  'Craighead',
#  'Crawford',
#  'Crittenden',
#  'Cross',
#  'Dallas',
#  'Desha',
#  'Drew',
#  'Faulkner',
#  'Franklin',
#  'Fulton',
#  'Garland',
#  'Grant',
#  'Greene',
#  'Hempstead',
#  'Hot Spring',
#  'Howard',
#  'Independence',
#  'Izard',
#  'Jackson',
#  'Jefferson',
#  'Johnson',
#  'Lafayette',
#  'Lawrence',
#  'Lee',
#  'Lincoln',
#  'Little River',
#  'Logan',
#  'Lonoke',
#  'Madison',
#  'Marion',
#  'Miller',
#  'Mississippi',
#  'Monroe',
#  'Montgomery',
#  'Nevada',
#  'Newton',
#  'Ouachita',
#  'Perry',
#  'Phillips',
#  'Pike',
#  'Poinsett',
#  'Polk',
#  'Pope',
#  'Prairie',
#  'Pulaski',
#  'Randolph',
#  'Saline',
#  'Scott',
#  'Searcy',
#  'Sebastian',
#  'Sevier',
#  'Sharp',
#  'St. Francis',
#  'Stone',
#  'Union',
#  'Unknown',
#  'Van Buren',
#  'Washington',
#  'White',
#  'Woodruff',
#  'Yell',
#  'Alameda',
#  'Alpine',
#  'Amador',
#  'Butte',
#  'Calaveras',
#  'Colusa',
#  'Contra Costa',
#  'Del Norte',
#  'El Dorado',
#  'Fresno',
#  'Glenn',
#  'Humboldt',
#  'Imperial',
#  'Inyo',
#  'Kern',
#  'Kings',
#  'Lake',
#  'Lassen',
#  'Los Angeles',
#  'Madera',
#  'Marin',
#  'Mariposa',
#  'Mendocino',
#  'Merced',
#  'Modoc',
#  'Mono',
#  'Monterey',
#  'Napa',
#  'Nevada',
#  'Orange',
#  'Placer',
#  'Plumas',
#  'Riverside',
#  'Sacramento',
#  'San Benito',
#  'San Bernardino',
#  'San Diego',
#  'San Francisco',
#  'San Joaquin',
#  'San Luis Obispo',
#  'San Mateo',
#  'Santa Barbara',
#  'Santa Clara',
#  'Santa Cruz',
#  'Shasta',
#  'Sierra',
#  'Siskiyou',
#  'Solano',
#  'Sonoma',
#  'Stanislaus',
#  'Sutter',
#  'Tehama',
#  'Trinity',
#  'Tulare',
#  'Tuolumne',
#  'Ventura',
#  'Yolo',
#  'Yuba',
#  'Adams',
#  'Alamosa',
#  'Arapahoe',
#  'Archuleta',
#  'Baca',
#  'Bent',
#  'Boulder',
#  'Broomfield',
#  'Chaffee',
#  'Cheyenne',
#  'Clear Creek',
#  'Conejos',
#  'Costilla',
#  'Crowley',
#  'Custer',
#  'Delta',
#  'Denver',
#  'Dolores',
#  'Douglas',
#  'Eagle',
#  'Elbert',
#  'El Paso',
#  'Fremont',
#  'Garfield',
#  'Gilpin',
#  'Grand',
#  'Gunnison',
#  'Hinsdale',
#  'Huerfano',
#  'Jackson',
#  'Jefferson',
#  'Kiowa',
#  'Kit Carson',
#  'Lake',
#  'La Plata',
#  'Larimer',
#  'Las Animas',
#  'Lincoln',
#  'Logan',
#  'Mesa',
#  'Mineral',
#  'Moffat',
#  'Montezuma',
#  'Montrose',
#  'Morgan',
#  'Otero',
#  'Ouray',
#  'Park',
#  'Phillips',
#  'Pitkin',
#  'Prowers',
#  'Pueblo',
#  'Rio Blanco',
#  'Rio Grande',
#  'Routt',
#  'Saguache',
#  'San Juan',
#  'San Miguel',
#  'Sedgwick',
#  'Summit',
#  'Teller',
#  'Washington',
#  'Weld',
#  'Yuma',
#  'Fairfield',
#  'Hartford',
#  'Litchfield',
#  'Middlesex',
#  'New Haven',
#  'New London',
#  'Tolland',
#  'Unknown',
#  'Windham',
#  'Kent',
#  'New Castle',
#  'Sussex',
#  'Unknown',
#  'District of Columbia',
#  'Alachua',
#  'Baker',
#  'Bay',
#  'Bradford',
#  'Brevard',
#  'Broward',
#  'Calhoun',
#  'Charlotte',
#  'Citrus',
#  'Clay',
#  'Collier',
#  'Columbia',
#  'DeSoto',
#  'Dixie',
#  'Duval',
#  'Escambia',
#  'Flagler',
#  'Franklin',
#  'Gadsden',
#  'Gilchrist',
#  'Glades',
#  'Gulf',
#  'Hamilton',
#  'Hardee',
#  'Hendry',
#  'Hernando',
#  'Highlands',
#  'Hillsborough',
#  'Holmes',
#  'Indian River',
#  'Jackson',
#  'Jefferson',
#  'Lafayette',
#  'Lake',
#  'Lee',
#  'Leon',
#  'Levy',
#  'Liberty',
#  'Madison',
#  'Manatee',
#  'Marion',
#  'Martin',
#  'Miami-Dade',
#  'Monroe',
#  'Nassau',
#  'Okaloosa',
#  'Okeechobee',
#  'Orange',
#  'Osceola',
#  'Palm Beach',
#  'Pasco',
#  'Pinellas',
#  'Polk',
#  'Putnam',
#  'Santa Rosa',
#  'Sarasota',
#  'Seminole',
#  'St. Johns',
#  'St. Lucie',
#  'Sumter',
#  'Suwannee',
#  'Taylor',
#  'Union',
#  'Unknown',
#  'Volusia',
#  'Wakulla',
#  'Walton',
#  'Washington',
#  'Appling',
#  'Atkinson',
#  'Bacon',
#  'Baker',
#  'Baldwin',
#  'Banks',
#  'Barrow',
#  'Bartow',
#  'Ben Hill',
#  'Berrien',
#  'Bibb',
#  'Bleckley',
#  'Brantley',
#  'Brooks',
#  'Bryan',
#  'Bulloch',
#  'Burke',
#  'Butts',
#  'Calhoun',
#  'Camden',
#  'Candler',
#  'Carroll',
#  'Catoosa',
#  'Charlton',
#  'Chatham',
#  'Chattahoochee',
#  'Chattooga',
#  'Cherokee',
#  'Clarke',
#  'Clay',
#  'Clayton',
#  'Clinch',
#  'Cobb',
#  'Coffee',
#  'Colquitt',
#  'Columbia',
#  'Cook',
#  'Coweta',
#  'Crawford',
#  'Crisp',
#  'Dade',
#  'Dawson',
#  'Decatur',
#  'DeKalb',
#  'Dodge',
#  'Dooly',
#  'Dougherty',
#  'Douglas',
#  'Early',
#  'Echols',
#  'Effingham',
#  'Elbert',
#  'Emanuel',
#  'Evans',
#  'Fannin',
#  'Fayette',
#  'Floyd',
#  'Forsyth',
#  'Franklin',
#  'Fulton',
#  'Gilmer',
#  'Glascock',
#  'Glynn',
#  'Gordon',
#  'Grady',
#  'Greene',
#  'Gwinnett',
#  'Habersham',
#  'Hall',
#  'Hancock',
#  'Haralson',
#  'Harris',
#  'Hart',
#  'Heard',
#  'Henry',
#  'Houston',
#  'Irwin',
#  'Jackson',
#  'Jasper',
#  'Jeff Davis',
#  'Jefferson',
#  'Jenkins',
#  'Johnson',
#  'Jones',
#  'Lamar',
#  'Lanier',
#  'Laurens',
#  'Lee',
#  'Liberty',
#  'Lincoln',
#  'Long',
#  'Lowndes',
#  'Lumpkin',
#  'Macon',
#  'Madison',
#  'Marion',
#  'McDuffie',
#  'McIntosh',
#  'Meriwether',
#  'Miller',
#  'Mitchell',
#  'Monroe',
#  'Montgomery',
#  'Morgan',
#  'Murray',
#  'Muscogee',
#  'Newton',
#  'Oconee',
#  'Oglethorpe',
#  'Paulding',
#  'Peach',
#  'Pickens',
#  'Pierce',
#  'Pike',
#  'Polk',
#  'Pulaski',
#  'Putnam',
#  'Quitman',
#  'Rabun',
#  'Randolph',
#  'Richmond',
#  'Rockdale',
#  'Schley',
#  'Screven',
#  'Seminole',
#  'Spalding',
#  'Stephens',
#  'Stewart',
#  'Sumter',
#  'Talbot',
#  'Taliaferro',
#  'Tattnall',
#  'Taylor',
#  'Telfair',
#  'Terrell',
#  'Thomas',
#  'Tift',
#  'Toombs',
#  'Towns',
#  'Treutlen',
#  'Troup',
#  'Turner',
#  'Twiggs',
#  'Union',
#  'Unknown',
#  'Upson',
#  'Walker',
#  'Walton',
#  'Ware',
#  'Warren',
#  'Washington',
#  'Wayne',
#  'Webster',
#  'Wheeler',
#  'White',
#  'Whitfield',
#  'Wilcox',
#  'Wilkes',
#  'Wilkinson',
#  'Worth',
#  'Unknown',
#  'Hawaii',
#  'Honolulu',
#  'Kalawao',
#  'Kauai',
#  'Maui',
#  'Ada',
#  'Adams',
#  'Bannock',
#  'Bear Lake',
#  'Benewah',
#  'Bingham',
#  'Blaine',
#  'Boise',
#  'Bonner',
#  'Bonneville',
#  'Boundary',
#  'Butte',
#  'Camas',
#  'Canyon',
#  'Caribou',
#  'Cassia',
#  'Clark',
#  'Clearwater',
#  'Custer',
#  'Elmore',
#  'Franklin',
#  'Fremont',
#  'Gem',
#  'Gooding',
#  'Idaho',
#  'Jefferson',
#  'Jerome',
#  'Kootenai',
#  'Latah',
#  'Lemhi',
#  'Lewis',
#  'Lincoln',
#  'Madison',
#  'Minidoka',
#  'Nez Perce',
#  'Oneida',
#  'Owyhee',
#  'Payette',
#  'Power',
#  'Shoshone',
#  'Teton',
#  'Twin Falls',
#  'Valley',
#  'Washington',
#  'Adams',
#  'Alexander',
#  'Bond',
#  'Boone',
#  'Brown',
#  'Bureau',
#  'Calhoun',
#  'Carroll',
#  'Cass',
#  'Champaign',
#  'Christian',
#  'Clark',
#  'Clay',
#  'Clinton',
#  'Coles',
#  'Cook',
#  'Crawford',
#  'Cumberland',
#  'DeKalb',
#  'De Witt',
#  'Douglas',
#  'DuPage',
#  'Edgar',
#  'Edwards',
#  'Effingham',
#  'Fayette',
#  'Ford',
#  'Franklin',
#  'Fulton',
#  'Gallatin',
#  'Greene',
#  'Grundy',
#  'Hamilton',
#  'Hancock',
#  'Hardin',
#  'Henderson',
#  'Henry',
#  'Iroquois',
#  'Jackson',
#  'Jasper',
#  'Jefferson',
#  'Jersey',
#  'Jo Daviess',
#  'Johnson',
#  'Kane',
#  'Kankakee',
#  'Kendall',
#  'Knox',
#  'Lake',
#  'LaSalle',
#  'Lawrence',
#  'Lee',
#  'Livingston',
#  'Logan',
#  'Macon',
#  'Macoupin',
#  'Madison',
#  'Marion',
#  'Marshall',
#  'Mason',
#  'Massac',
#  'McDonough',
#  'McHenry',
#  'McLean',
#  'Menard',
#  'Mercer',
#  'Monroe',
#  'Montgomery',
#  'Morgan',
#  'Moultrie',
#  'Ogle',
#  'Peoria',
#  'Perry',
#  'Piatt',
#  'Pike',
#  'Pope',
#  'Pulaski',
#  'Putnam',
#  'Randolph',
#  'Richland',
#  'Rock Island',
#  'Saline',
#  'Sangamon',
#  'Schuyler',
#  'Scott',
#  'Shelby',
#  'Stark',
#  'St. Clair',
#  'Stephenson',
#  'Tazewell',
#  'Union',
#  'Vermilion',
#  'Wabash',
#  'Warren',
#  'Washington',
#  'Wayne',
#  'White',
#  'Whiteside',
#  'Will',
#  'Williamson',
#  'Winnebago',
#  'Woodford',
#  'Adams',
#  'Allen',
#  'Bartholomew',
#  'Benton',
#  'Blackford',
#  'Boone',
#  'Brown',
#  'Carroll',
#  'Cass',
#  'Clark',
#  'Clay',
#  'Clinton',
#  'Crawford',
#  'Daviess',
#  'Dearborn',
#  'Decatur',
#  'DeKalb',
#  'Delaware',
#  'Dubois',
#  'Elkhart',
#  'Fayette',
#  'Floyd',
#  'Fountain',
#  'Franklin',
#  'Fulton',
#  'Gibson',
#  'Grant',
#  'Greene',
#  'Hamilton',
#  'Hancock',
#  'Harrison',
#  'Hendricks',
#  'Henry',
#  'Howard',
#  'Huntington',
#  'Jackson',
#  'Jasper',
#  'Jay',
#  'Jefferson',
#  'Jennings',
#  'Johnson',
#  'Knox',
#  'Kosciusko',
#  'LaGrange',
#  'Lake',
#  'LaPorte',
#  'Lawrence',
#  'Madison',
#  'Marion',
#  'Marshall',
#  'Martin',
#  'Miami',
#  'Monroe',
#  'Montgomery',
#  'Morgan',
#  'Newton',
#  'Noble',
#  'Ohio',
#  'Orange',
#  'Owen',
#  'Parke',
#  'Perry',
#  'Pike',
#  'Porter',
#  'Posey',
#  'Pulaski',
#  'Putnam',
#  'Randolph',
#  'Ripley',
#  'Rush',
#  'Scott',
#  'Shelby',
#  'Spencer',
#  'Starke',
#  'Steuben',
#  'St. Joseph',
#  'Sullivan',
#  'Switzerland',
#  'Tippecanoe',
#  'Tipton',
#  'Union',
#  'Vanderburgh',
#  'Vermillion',
#  'Vigo',
#  'Wabash',
#  'Warren',
#  'Warrick',
#  'Washington',
#  'Wayne',
#  'Wells',
#  'White',
#  'Whitley',
#  'Adair',
#  'Adams',
#  'Allamakee',
#  'Appanoose',
#  'Audubon',
#  'Benton',
#  'Black Hawk',
#  'Boone',
#  'Bremer',
#  'Buchanan',
#  'Buena Vista',
#  'Butler',
#  'Calhoun',
#  'Carroll',
#  'Cass',
#  'Cedar',
#  'Cerro Gordo',
#  'Cherokee',
#  'Chickasaw',
#  'Clarke',
#  'Clay',
#  'Clayton',
#  'Clinton',
#  'Crawford',
#  'Dallas',
#  'Davis',
#  'Decatur',
#  'Delaware',
#  'Des Moines',
#  'Dickinson',
#  'Dubuque',
#  'Emmet',
#  'Fayette',
#  'Floyd',
#  'Franklin',
#  'Fremont',
#  'Greene',
#  'Grundy',
#  'Guthrie',
#  'Hamilton',
#  'Hancock',
#  'Hardin',
#  'Harrison',
#  'Henry',
#  'Howard',
#  'Humboldt',
#  'Ida',
#  'Iowa',
#  'Jackson',
#  'Jasper',
#  'Jefferson',
#  'Johnson',
#  'Jones',
#  'Keokuk',
#  'Kossuth',
#  'Lee',
#  'Linn',
#  'Louisa',
#  'Lucas',
#  'Lyon',
#  'Madison',
#  'Mahaska',
#  'Marion',
#  'Marshall',
#  'Mills',
#  'Mitchell',
#  'Monona',
#  'Monroe',
#  'Montgomery',
#  'Muscatine',
#  "O'Brien",
#  'Osceola',
#  'Page',
#  'Palo Alto',
#  'Plymouth',
#  'Pocahontas',
#  'Polk',
#  'Pottawattamie',
#  'Poweshiek',
#  'Ringgold',
#  'Sac',
#  'Scott',
#  'Shelby',
#  'Sioux',
#  'Story',
#  'Tama',
#  'Taylor',
#  'Union',
#  'Unknown',
#  'Van Buren',
#  'Wapello',
#  'Warren',
#  'Washington',
#  'Wayne',
#  'Webster',
#  'Winnebago',
#  'Winneshiek',
#  'Woodbury',
#  'Worth',
#  'Wright',
#  'Allen',
#  'Anderson',
#  'Atchison',
#  'Barber',
#  'Barton',
#  'Bourbon',
#  'Brown',
#  'Butler',
#  'Chase',
#  'Chautauqua',
#  'Cherokee',
#  'Cheyenne',
#  'Clark',
#  'Clay',
#  'Cloud',
#  'Coffey',
#  'Comanche',
#  'Cowley',
#  'Crawford',
#  'Decatur',
#  'Dickinson',
#  'Doniphan',
#  'Douglas',
#  'Edwards',
#  'Elk',
#  'Ellis',
#  'Ellsworth',
#  'Finney',
#  'Ford',
#  'Franklin',
#  'Geary',
#  'Gove',
#  'Graham',
#  'Grant',
#  'Gray',
#  'Greeley',
#  'Greenwood',
#  'Hamilton',
#  'Harper',
#  'Harvey',
#  'Haskell',
#  'Hodgeman',
#  'Jackson',
#  'Jefferson',
#  'Jewell',
#  'Johnson',
#  'Kearny',
#  'Kingman',
#  'Kiowa',
#  'Labette',
#  'Lane',
#  'Leavenworth',
#  'Lincoln',
#  'Linn',
#  'Logan',
#  'Lyon',
#  'Marion',
#  'Marshall',
#  'McPherson',
#  'Meade',
#  'Miami',
#  'Mitchell',
#  'Montgomery',
#  'Morris',
#  'Morton',
#  'Nemaha',
#  'Neosho',
#  'Ness',
#  'Norton',
#  'Osage',
#  'Osborne',
#  'Ottawa',
#  'Pawnee',
#  'Phillips',
#  'Pottawatomie',
#  'Pratt',
#  'Rawlins',
#  'Reno',
#  'Republic',
#  'Rice',
#  'Riley',
#  'Rooks',
#  'Rush',
#  'Russell',
#  'Saline',
#  'Scott',
#  'Sedgwick',
#  'Seward',
#  'Shawnee',
#  'Sheridan',
#  'Sherman',
#  'Smith',
#  'Stafford',
#  'Stanton',
#  'Stevens',
#  'Sumner',
#  'Thomas',
#  'Trego',
#  'Unknown',
#  'Wabaunsee',
#  'Wallace',
#  'Washington',
#  'Wichita',
#  'Wilson',
#  'Woodson',
#  'Wyandotte',
#  ...]

# %%
dfhere['county'][1872] = 'New York'
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dfhere['county'][1872]
# Out:
# 'New York'

# %%
dfhere['CTYNAME'] = dfhere['county'] + ', ' + dfhere['state']

# %%
x = dfhere['state'] == 'NY'

dfhere[x]
# Out:
#             date         county  ... probable_deaths            CTYNAME
# 1845  2021-01-11         Albany  ...             NaN         Albany, NY
# 1846  2021-01-11       Allegany  ...             NaN       Allegany, NY
# 1847  2021-01-11         Broome  ...             NaN         Broome, NY
# 1848  2021-01-11    Cattaraugus  ...             NaN    Cattaraugus, NY
# 1849  2021-01-11         Cayuga  ...             NaN         Cayuga, NY
# 1850  2021-01-11     Chautauqua  ...             NaN     Chautauqua, NY
# 1851  2021-01-11        Chemung  ...             NaN        Chemung, NY
# 1852  2021-01-11       Chenango  ...             NaN       Chenango, NY
# 1853  2021-01-11        Clinton  ...             NaN        Clinton, NY
# 1854  2021-01-11       Columbia  ...             NaN       Columbia, NY
# 1855  2021-01-11       Cortland  ...             NaN       Cortland, NY
# 1856  2021-01-11       Delaware  ...             NaN       Delaware, NY
# 1857  2021-01-11       Dutchess  ...             NaN       Dutchess, NY
# 1858  2021-01-11           Erie  ...             NaN           Erie, NY
# 1859  2021-01-11          Essex  ...             NaN          Essex, NY
# 1860  2021-01-11       Franklin  ...             NaN       Franklin, NY
# 1861  2021-01-11         Fulton  ...             NaN         Fulton, NY
# 1862  2021-01-11        Genesee  ...             NaN        Genesee, NY
# 1863  2021-01-11         Greene  ...             NaN         Greene, NY
# 1864  2021-01-11       Hamilton  ...             NaN       Hamilton, NY
# 1865  2021-01-11       Herkimer  ...             NaN       Herkimer, NY
# 1866  2021-01-11      Jefferson  ...             NaN      Jefferson, NY
# 1867  2021-01-11          Lewis  ...             NaN          Lewis, NY
# 1868  2021-01-11     Livingston  ...             NaN     Livingston, NY
# 1869  2021-01-11        Madison  ...             NaN        Madison, NY
# 1870  2021-01-11         Monroe  ...             NaN         Monroe, NY
# 1871  2021-01-11     Montgomery  ...             NaN     Montgomery, NY
# 1872  2021-01-11       New York  ...             NaN       New York, NY
# 1873  2021-01-11  New York City  ...          4841.0  New York City, NY
# 1874  2021-01-11        Niagara  ...             NaN        Niagara, NY
# 1875  2021-01-11         Oneida  ...             NaN         Oneida, NY
# 1876  2021-01-11       Onondaga  ...             NaN       Onondaga, NY
# 1877  2021-01-11        Ontario  ...             NaN        Ontario, NY
# 1878  2021-01-11         Orange  ...             NaN         Orange, NY
# 1879  2021-01-11        Orleans  ...             NaN        Orleans, NY
# 1880  2021-01-11         Oswego  ...             NaN         Oswego, NY
# 1881  2021-01-11         Otsego  ...             NaN         Otsego, NY
# 1882  2021-01-11         Putnam  ...             NaN         Putnam, NY
# 1883  2021-01-11     Rensselaer  ...             NaN     Rensselaer, NY
# 1884  2021-01-11       Rockland  ...             NaN       Rockland, NY
# 1885  2021-01-11       Saratoga  ...             NaN       Saratoga, NY
# 1886  2021-01-11    Schenectady  ...             NaN    Schenectady, NY
# 1887  2021-01-11      Schoharie  ...             NaN      Schoharie, NY
# 1888  2021-01-11       Schuyler  ...             NaN       Schuyler, NY
# 1889  2021-01-11         Seneca  ...             NaN         Seneca, NY
# 1890  2021-01-11        Steuben  ...             NaN        Steuben, NY
# 1891  2021-01-11   St. Lawrence  ...             NaN   St. Lawrence, NY
# 1892  2021-01-11        Suffolk  ...             NaN        Suffolk, NY
# 1893  2021-01-11       Sullivan  ...             NaN       Sullivan, NY
# 1894  2021-01-11          Tioga  ...             NaN          Tioga, NY
# 1895  2021-01-11       Tompkins  ...             NaN       Tompkins, NY
# 1896  2021-01-11         Ulster  ...             NaN         Ulster, NY
# 1897  2021-01-11         Warren  ...             NaN         Warren, NY
# 1898  2021-01-11     Washington  ...             NaN     Washington, NY
# 1899  2021-01-11          Wayne  ...             NaN          Wayne, NY
# 1900  2021-01-11    Westchester  ...             NaN    Westchester, NY
# 1901  2021-01-11        Wyoming  ...             NaN        Wyoming, NY
# 1902  2021-01-11          Yates  ...             NaN          Yates, NY
#
# [58 rows x 11 columns]

# %%
dfhere.sort_values(by = 'CTYNAME', inplace=True)

# %%
exon.sort_values(by = 'CTYNAME', inplace=True, ignore_index=True)

# %%
exon['POPESTIMATE'][219] = 1147532
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
exon['POPESTIMATE'][219]
# Out:
# 1147532.0

# %%
exon['POPESTIMATE'][2653] = 998684
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
exon['POPESTIMATE'][2653]
# Out:
# 998684.0

# %%
DFTEST = pd.merge(exon, dfhere, on='CTYNAME', how='outer', indicator=True)

# %%
DFTEST['date_y'].value_counts()
# Out:
# 2021-01-11    3257
# Name: date_y, dtype: int64

# %%
X = DFTEST['_merge'] == 'right_only'

y = DFTEST[X].index

# %%
DFTEST.drop(labels=y, axis=0, inplace=True)

# %%
x = ['date_x', 'state_x',	'fips_x',	'cases_x', 'deaths_x',	'confirmed_cases_x',	'confirmed_deaths_x',	'probable_cases_x',	'probable_deaths_x']

DFTEST.drop(labels=x, axis=1, inplace=True)

# %%
x = exon['CTYNAME'].duplicated()

exon[x]
# Out:
#       Unnamed: 0  Unnamed: 0.1        CTYNAME  ...  SOMETIMES  FREQUENTLY  ALWAYS
# 123         1918          1917  Baltimore, MD  ...      0.043       0.142   0.777
# 892          219           218    Fairfax, VA  ...      0.054       0.163   0.748
# 971          224           223   Franklin, VA  ...      0.069       0.189   0.570
# 2411         268           267   Richmond, VA  ...      0.092       0.275   0.541
# 2424         269           268    Roanoke, VA  ...      0.077       0.205   0.607
# 2653        1630          1629  St. Louis, MO  ...      0.069       0.182   0.697
#
# [6 rows x 113 columns]

# %%
x = DFTEST['CTYNAME'].duplicated()

DFTEST[x]

Y = [123, 124, 895, 896, 976, 977, 2432, 2419, 2663, 2665]

DFTEST.drop(labels = Y, axis=0, inplace=True)

# %%
DFTEST.isnull().sum()
# Out:
# Unnamed: 0               0
# Unnamed: 0.1             0
# CTYNAME                  0
# STCOU                 3129
# Landarea                 0
#                       ...
# confirmed_cases_y      850
# confirmed_deaths_y    1313
# probable_cases_y      1367
# probable_deaths_y     1992
# _merge                   0
# Length: 115, dtype: int64

# %%
exon.shape
# Out:
# (3128, 113)

# %%
DFTEST.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  ... probable_deaths_y  _merge
# 0       779.0         778.0  ...               5.0    both
# 1      1956.0        1955.0  ...               5.0    both
# 2       190.0         189.0  ...               NaN    both
# 3      2537.0        2536.0  ...              31.0    both
# 4      2244.0        2243.0  ...               NaN    both
#
# [5 rows x 115 columns]

# %%
DFTEST.rename(columns={'county state_y':'county state',	'fips_y':'fips', 'cases_y':'cases',	'deaths_y':'deaths',	'confirmed_cases_y':'confirmed_cases', 'confirmed_deaths_y':'confirmed_deaths',	'probable_cases_y':'probable_cases',	'probable_deaths_y':'probable_deaths'}, inplace=True)

# %%
x = DFTEST['CTYNAME'].duplicated()

DFTEST[x]

y = [2417, 2434]

# %%
DFTEST.drop(labels=y, axis=0, inplace=True)

# %%
DFTEST['Landarea'] = DFTEST['Landarea'].astype(float)

# %%
DFTEST['popdensity'] = DFTEST['POPESTIMATE']/DFTEST['Landarea']

# %%
DFTEST.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1        CTYNAME  ...  probable_deaths  _merge  popdensity
# 0       779.0         778.0  Abbeville, SC  ...              5.0    both   48.260596
# 1      1956.0        1955.0     Acadia, LA  ...              5.0    both   94.472783
# 2       190.0         189.0   Accomack, VA  ...              NaN    both   67.936428
# 3      2537.0        2536.0        Ada, ID  ...             31.0    both  457.956447
# 4      2244.0        2243.0      Adair, IA  ...              NaN    both   12.555298
#
# [5 rows x 116 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
gabba = []

for x in DFTEST['POPESTIMATE2019']:
  if x > 2000000:
    gabba.append(1)
  else:
    gabba.append(0)

DFTEST['binfinder']  = gabba

# %%
DFTEST['date_y'].value_counts()
# Out:
# 2021-01-11    3127
# Name: date_y, dtype: int64

# %%
DFTEST.to_csv('dftestt.csv')

# %%
a = DFTEST['binfinder'] == 1

b = DFTEST[a]

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm
model = ols('deaths ~ POPESTIMATE + ALWAYS', data =b).fit()

model.summary()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=14
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 deaths   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.829
# Method:                 Least Squares   F-statistic:                     32.53
# Date:                Tue, 12 Jan 2021   Prob (F-statistic):           2.41e-05
# Time:                        01:02:38   Log-Likelihood:                -118.88
# No. Observations:                  14   AIC:                             243.8
# Df Residuals:                      11   BIC:                             245.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    5960.8153   8595.371      0.693      0.502    -1.3e+04    2.49e+04
# POPESTIMATE     0.0014      0.000      8.044      0.000       0.001       0.002
# ALWAYS      -9415.6745   1.13e+04     -0.832      0.423   -3.43e+04    1.55e+04
# ==============================================================================
# Omnibus:                        0.815   Durbin-Watson:                   1.648
# Prob(Omnibus):                  0.665   Jarque-Bera (JB):                0.491
# Skew:                           0.429   Prob(JB):                        0.782
# Kurtosis:                       2.676   Cond. No.                     1.64e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.64e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model = ols('cases ~ POPESTIMATE + popdensity', data = b).fit()

model.summary()
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=14
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  cases   R-squared:                       0.902
# Model:                            OLS   Adj. R-squared:                  0.884
# Method:                 Least Squares   F-statistic:                     50.55
# Date:                Tue, 12 Jan 2021   Prob (F-statistic):           2.85e-06
# Time:                        01:02:38   Log-Likelihood:                -174.42
# No. Observations:                  14   AIC:                             354.8
# Df Residuals:                      11   BIC:                             356.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -2.884e+04   3.96e+04     -0.729      0.481   -1.16e+05    5.82e+04
# POPESTIMATE     0.0943      0.010      9.724      0.000       0.073       0.116
# popdensity    -12.2192     13.351     -0.915      0.380     -41.605      17.166
# ==============================================================================
# Omnibus:                        0.807   Durbin-Watson:                   2.113
# Prob(Omnibus):                  0.668   Jarque-Bera (JB):                0.437
# Skew:                          -0.411   Prob(JB):                        0.804
# Kurtosis:                       2.729   Cond. No.                     8.62e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.62e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
exon['popdensity'] = exon['POPESTIMATE2019']/exon['Landarea']

# %%
ax = sns.regplot(x = "POPESTIMATE", y = "cases", data = exon)

# %%
exon.head()
exon['ratio'] = exon['AGE7074_TOT']/exon['POPESTIMATE']

# %%
exon.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1        CTYNAME  ...  ALWAYS  popdensity     ratio
# 0         779           778  Abbeville, SC  ...   0.371   48.260596  0.060505
# 1        1956          1955     Acadia, LA  ...   0.362   94.472783  0.040132
# 2         190           189   Accomack, VA  ...   0.824   67.936428  0.064921
# 3        2537          2536        Ada, ID  ...   0.526  457.956447  0.041068
# 4        2244          2243      Adair, IA  ...   0.364   12.555298  0.048798
#
# [5 rows x 115 columns]

# %%
exon['POPESTIMATE'].sort_values()
# Out:
# 1497         272.0
# 1474         404.0
# 87           463.0
# 214          465.0
# 2229         487.0
#            ...
# 1774     4485414.0
# 1204     4713325.0
# 626      5150233.0
# 1704    10039107.0
# 2053           NaN
# Name: POPESTIMATE, Length: 3128, dtype: float64

# %%
dftimed = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')

# %%
gabba = []
for x in dftimed['county']:
  x = x.split()
  if x[-1] == 'city':
    x.pop()
    x = ' '.join(x)
    gabba.append(x)
  elif x[-1] == 'City':
    x.pop()
    x = ' '.join(x)
    gabba.append(x)
  else:
    x = ' '.join(x)
    gabba.append(x)
dftimed['county'] = gabba

# %%
galla = []
for x in dftimed['state']:
  galla.append(us_state_abbrev[x])

dftimed['state'] = galla

# %%
dftimed['CTYNAME'] = dftimed['county'] + ', ' + dftimed['state']

# %%
x = pd.to_datetime(dftimed['date'], infer_datetime_format=True)

# %%
x = dftimed['date'] == '2020-06-08'

dftimed[x]
# Out:
#               date      county state     fips  cases  deaths         CTYNAME
# 218425  2020-06-08     Autauga    AL   1001.0    273     5.0     Autauga, AL
# 218426  2020-06-08     Baldwin    AL   1003.0    335     9.0     Baldwin, AL
# 218427  2020-06-08     Barbour    AL   1005.0    198     1.0     Barbour, AL
# 218428  2020-06-08        Bibb    AL   1007.0     82     1.0        Bibb, AL
# 218429  2020-06-08      Blount    AL   1009.0     75     1.0      Blount, AL
# ...            ...         ...   ...      ...    ...     ...             ...
# 221513  2020-06-08  Sweetwater    WY  56037.0     33     0.0  Sweetwater, WY
# 221514  2020-06-08       Teton    WY  56039.0    100     1.0       Teton, WY
# 221515  2020-06-08       Uinta    WY  56041.0     25     0.0       Uinta, WY
# 221516  2020-06-08    Washakie    WY  56043.0     38     3.0    Washakie, WY
# 221517  2020-06-08      Weston    WY  56045.0      1     0.0      Weston, WY
#
# [3093 rows x 7 columns]

# %%
x= dftimed.loc[dftimed['county'] == 'Cook']

some = x.loc[x['state']=='IL']

# %%
conna = ['Connecticut', 'Delaware', 'District of Columbia', 'Hawaii', 'Illinois', 'Kentucky', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'New Jersey', 'New Mexico', 'New York', 'Pennsylvania', 'Rhode Island', 'Utah']

# %%
galla = []
for x in conna:
  galla.append(us_state_abbrev[x])

conna = galla

# %%
dfhere.head()
# Out:
#             date     county  ... probable_deaths        CTYNAME
# 2413  2021-01-11  Abbeville  ...             5.0  Abbeville, SC
# 1120  2021-01-11     Acadia  ...             5.0     Acadia, LA
# 2920  2021-01-11   Accomack  ...             NaN   Accomack, VA
# 556   2021-01-11        Ada  ...            31.0        Ada, ID
# 794   2021-01-11      Adair  ...             NaN      Adair, IA
#
# [5 rows x 11 columns]

# %%
dftimed.head()
# Out:
#          date     county state     fips  cases  deaths        CTYNAME
# 0  2020-01-21  Snohomish    WA  53061.0      1     0.0  Snohomish, WA
# 1  2020-01-22  Snohomish    WA  53061.0      1     0.0  Snohomish, WA
# 2  2020-01-23  Snohomish    WA  53061.0      1     0.0  Snohomish, WA
# 3  2020-01-24       Cook    IL  17031.0      1     0.0       Cook, IL
# 4  2020-01-24  Snohomish    WA  53061.0      1     0.0  Snohomish, WA

# %%
def growth1(x):
  alacart1 = []
  'establishes the day by day growth rates'
  for y, z in enumerate(x['cases']):
    if y == 0:
      alacart1.append(0)
      h = z
    else:
      a = (np.log(z) - np.log(h)) *100
      alacart1.append(a)
      h = z
  return alacart1

# %%
def weekaverage(x):
  'weekly average growth rates'
  sometin = []
  sometinelse = []
  for y in x:
    if len(sometin) == 7:
      z = np.mean(sometin)
      sometinelse.append(y)
      sometin = []
      sometin.append(y)
    else:
      sometin.append(y)
  return sometinelse

# %%
def growth(x):
  alacart = []
  'establishes weekly average growth rates befoer and after'
  for y, z in enumerate(x['cases']):
    if y == 0:
      alacart.append(0)
      h = z
    else:
      a = (np.log(z) - np.log(h)) *100
      alacart.append(a)
      h = z
  averagesperweek = weekaverage(alacart)
  return averagesperweek

# %%
dfhere.head()
# Out:
#             date     county  ... probable_deaths        CTYNAME
# 2413  2021-01-11  Abbeville  ...             5.0  Abbeville, SC
# 1120  2021-01-11     Acadia  ...             5.0     Acadia, LA
# 2920  2021-01-11   Accomack  ...             NaN   Accomack, VA
# 556   2021-01-11        Ada  ...            31.0        Ada, ID
# 794   2021-01-11      Adair  ...             NaN      Adair, IA
#
# [5 rows x 11 columns]

# %%
g = dftimed['CTYNAME'].value_counts()

# %%
g = pd.DataFrame(g)

# %%
y = g.index

# %%
sommma = []
for x in y:
  x = x.split()
  if x[0] == 'Unknown,':
    x = (' ').join(x)
    sommma.append(x)

# %%
sommma
# Out:
# ['Unknown, RI',
#  'Unknown, NJ',
#  'Unknown, PR',
#  'Unknown, GU',
#  'Unknown, MA',
#  'Unknown, LA',
#  'Unknown, AR',
#  'Unknown, GA',
#  'Unknown, VT',
#  'Unknown, MN',
#  'Unknown, MI',
#  'Unknown, CT',
#  'Unknown, UT',
#  'Unknown, FL',
#  'Unknown, DE',
#  'Unknown, MD',
#  'Unknown, IA',
#  'Unknown, NH',
#  'Unknown, ME',
#  'Unknown, AK',
#  'Unknown, ND',
#  'Unknown, TN',
#  'Unknown, IL',
#  'Unknown, NE',
#  'Unknown, WA',
#  'Unknown, OK',
#  'Unknown, MP',
#  'Unknown, WI',
#  'Unknown, VI',
#  'Unknown, KS',
#  'Unknown, CO',
#  'Unknown, NV',
#  'Unknown, KY',
#  'Unknown, NM',
#  'Unknown, MO',
#  'Unknown, AZ',
#  'Unknown, VA',
#  'Unknown, HI',
#  'Unknown, MS',
#  'Unknown, ID',
#  'Unknown, NY',
#  'Unknown, CA',
#  'Unknown, SD',
#  'Unknown, IN',
#  'Unknown, WY',
#  'Unknown, OH',
#  'Unknown, SC',
#  'Unknown, MT',
#  'Unknown, PA',
#  'Unknown, WV',
#  'Unknown, OR',
#  'Unknown, TX']

# %%
g.drop(labels=sommma, axis=0, inplace=True)

# %%
dftimed.head()
# Out:
#          date     county state     fips  cases  deaths        CTYNAME
# 0  2020-01-21  Snohomish    WA  53061.0      1     0.0  Snohomish, WA
# 1  2020-01-22  Snohomish    WA  53061.0      1     0.0  Snohomish, WA
# 2  2020-01-23  Snohomish    WA  53061.0      1     0.0  Snohomish, WA
# 3  2020-01-24       Cook    IL  17031.0      1     0.0       Cook, IL
# 4  2020-01-24  Snohomish    WA  53061.0      1     0.0  Snohomish, WA

# %%
dftimed.index = dftimed['date']

# %%
dftimedimprov = dftimed.loc['2020-02-15':'2020-12-11']

# %%
alright = dftimedimprov.index

# %%
len(alright)
# Out:
# 819741

# %%
som = [x for x in range(287)]

# %%
def casegrowth13(x):
  alacart1 = []
  'establishes the day by day growth rates'
  for count, z in enumerate(x['cases']):
    if count == 0:
      alacart1.append(0)
      h = z
    else:
      a = (np.log(z) - np.log(h)) *100
      alacart1.append(a)
      h= z
  return alacart1

# %%
some = [x for x in range(len(dftimed))]

dftimed['index'] = some

# %%
dftimed.index = dftimed['index']

# %%
dftimed.drop(labels = 'index', axis=1, inplace=True)

# %%
import datetime
from datetime import timedelta

# %%
a = dftimed['county'] == 'Unknown'
b = dftimed[a] 
c = b.index
dftimed.drop(labels=c, inplace=True)

# %%
for x in dftimed['cases']:
  if x == 0:
    x=1

# %%
def casegrowth12(x):
  alacart1 = []
  'establishes the day by day growth rates'
  for count, z in enumerate(x['cases']):
    if count == 0:
      alacart1.append(0)
      h = z
    else:
      a = (np.log(z) - np.log(h)) *100
      alacart1.append(a)
      h = z
  return alacart1

# %%
ag = casegrowth12(dftimed)

# %%
DFTEST['casespercapita'] = (DFTEST['cases']/DFTEST['POPESTIMATE'])*100000
DFTEST['deathspercapita'] = (DFTEST['deaths']/DFTEST['POPESTIMATE'])*100000

# %%
DFTEST.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  ... casespercapita  deathspercapita
# 0       779.0         778.0  ...    5663.146736       106.005626
# 1      1956.0        1955.0  ...    8771.053268       265.936014
# 2       190.0         189.0  ...    6303.379131        92.833271
# 3      2537.0        2536.0  ...    8469.913017        77.659904
# 4      2244.0        2243.0  ...    9228.187919       279.642058
#
# [5 rows x 119 columns]

# %%
model = ols('casespercapita ~ POPESTIMATE', data=DFTEST).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         casespercapita   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     9.509
# Date:                Tue, 12 Jan 2021   Prob (F-statistic):            0.00206
# Time:                        01:03:51   Log-Likelihood:                -29896.
# No. Observations:                3126   AIC:                         5.980e+04
# Df Residuals:                    3124   BIC:                         5.981e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    7462.0973     64.573    115.560      0.000    7335.487    7588.708
# POPESTIMATE    -0.0006      0.000     -3.084      0.002      -0.001      -0.000
# ==============================================================================
# Omnibus:                     5190.581   Durbin-Watson:                   1.965
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         12972918.480
# Skew:                          10.440   Prob(JB):                         0.00
# Kurtosis:                     317.903   Cond. No.                     3.59e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.59e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model = ols('cases ~ POPESTIMATE', data=DFTEST).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  cases   R-squared:                       0.924
# Model:                            OLS   Adj. R-squared:                  0.924
# Method:                 Least Squares   F-statistic:                 3.808e+04
# Date:                Tue, 12 Jan 2021   Prob (F-statistic):               0.00
# Time:                        01:03:54   Log-Likelihood:                -32151.
# No. Observations:                3126   AIC:                         6.431e+04
# Df Residuals:                    3124   BIC:                         6.432e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    -787.6587    132.877     -5.928      0.000   -1048.193    -527.124
# POPESTIMATE     0.0756      0.000    195.144      0.000       0.075       0.076
# ==============================================================================
# Omnibus:                     2193.568   Durbin-Watson:                   1.953
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3613804.673
# Skew:                           1.807   Prob(JB):                         0.00
# Kurtosis:                     169.530   Cond. No.                     3.59e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.59e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
